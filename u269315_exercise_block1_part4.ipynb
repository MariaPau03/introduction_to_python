# %%
#We need to use the FASTA_iterator
#To handle the case-sensitive requirement, it is best to convert every identifier to lowercase (.lower()) as you read them
#How to visualize the 4 required outputs?
    # UNION: every unique ID found across all files -> set {}
    # INTERSECTION: IDs that appear in every single file -> set{}
    # FREQUENCY: A counter for how many files each ID lives in -> dict
    # SPECIFIC: IDs that belong to File A but not File B or C -> dict{"":""}

def compare_fasta_file_identifiers(fasta_filename_list):
    #Initialize data structures:
    files_with_id_dict={} #empty dictionary to store the filenames and IDs
    from u269315_S04 import FASTA_iterator
    for fasta_file in fasta_filename_list:
        current_file_id_set = set() #Creates a set of IDs for this specific file
        #Use my FASTA_iterator Generator here! (handles opening the file already)
        for header, sequence in FASTA_iterator(fasta_file):
            cleaned_id = header.strip().lower() # Strings are immutable, so that's why I create a new lowercase version
            current_file_id_set.add(cleaned_id)
        #After the iterator finishes, save the set into the main dictionary 
        files_with_id_dict[fasta_file] = current_file_id_set #I'm adding the cleaned and lowercase headers for each file, as it us under the for loop that iterates for each file

    #Now do the maths that the exercise is asking! For that it is used the dictionary
    #dictionaries cannot have duplicates, so for the unique part is done (i think)
    # PREPARATION: Extract just the sets from your dictionary into a list
    # This makes it easier to compare them ALL at once. ".get()" is to look up a single specific value
    all_ids_sets = files_with_id_dict.values() #now all_ids_sets is a collection of all the sets from every file

    # 1. UNION ( All uniq IDs across ALL files)
    # Hint: In Python, you can use set.union(*ALL_SETS)
    union_ids = set.union(*all_ids_sets) #contains every set of ids

    # 2. INTERSECTION (IDs in EVERY file)
    # Hint: In Python, you can use set.intersection(*ALL_SETS)
    intersection_ids = set.intersection(*all_ids_sets)

    # 3. FREQUENCY
    # Logic: For every unique ID we found (the Union), count how many files it's in.
    frequency_dict = {} #the exercise tells that frequency should be in a dictionary format
    for uniq_ids in union_ids:
        count = 0
        for id_set in all_ids_sets:
            if uniq_ids in id_set:
                count += 1
        frequency_dict[uniq_ids] = count #dictionary[key] = value, go to that dictionary, create an entry called "key" and store "value" inside it :)
    
    # 4. SPECIFIC
    # Logic: For each file, find IDs that don't exist in ANY other file.
    specific_dict = {}

    for fasta_file, current_file_id_set in files_with_id_dict.items(): #.items() returns a list of tuples for each key-value pari in a dictionary
        other_ids = set() #create an empty set of other_ids
        # Get all IDs from all files EXCEPT the current one
        for other_files, other_set in files_with_id_dict.items():
            if fasta_file != other_files:
                other_ids = other_ids.union(other_set)
        # Specific IDs = IDs in this file MINUS IDs in all other files
        specific_dict[fasta_file] = current_file_id_set - other_ids


    return{ #we use {} becasuse it will return dictionaries and sets and hese go with {} not with () or [])
        "Intersection" : intersection_ids,
        "Union" : union_ids,
        "Frequency" : frequency_dict,
        "Specificity" : specific_dict,
    }

compare_fasta_file_identifiers(["uniprot_sprot_sample.fasta", "uniprot_sprot_sample2.fasta", "uniprot_sprot_sample3.fasta"])
# import pprint
# my_files = ["uniprot_sprot_sample.fasta", "uniprot_sprot_sample2.fasta", "uniprot_sprot_sample3.fasta"]
# final_result = compare_fasta_file_identifiers(my_files)
# #pprint.pprint(final_result)



# # Assuming 'your_data' is the dictionary you provided
# pp = pprint.PrettyPrinter(indent=1, width=80, compact=False)

# # To print to console:
# pp.pprint(final_result)

# # To format it as a string (useful for logging or writing to files):
# formatted_string = pp.pformat(final_result)
# Out:
# {'Intersection': {'a0jmz3',
#   'a0pj23',
#   'a1krk6',
#   'a2bfl2',
#   'a2ce44',
#   'a4k2u9',
#   'a4se48',
#   'a5h447',
#   'a5wwb6',
#   'a6qm04',
#   'a9jr22',
#   'a9jr44',
#   'a9mpx1',
#   'b0blk0',
#   'b0blk7',
#   'b0blk9',
#   'b1hyt6',
#   'b2c4j2',
#   'b2fm90',
#   'b2mw50',
#   'b2zdy1',
#   'b4spv6',
#   'b4t660',
#   'b4ti40',
#   'b4tvs2',
#   'b5f683',
#   'b5fv58',
#   'b5qz27',
#   'b5ree9',
#   'b7lqb7',
#   'g5eem5',
#   'o05839',
#   'o23878',
#   'o23880',
#   'o42766',
#   'o43149',
#   'o43264',
#   'o44218',
#   'o44219',
#   'o48626',
#   'o49995',
#   'o49996',
#   'o49997',
#   'o49998',
#   'o54692',
#   'o55703',
#   'o55704',
#   'o55705',
#   'o55706',
#   'o55709',
#   'o55710',
#   'o55713',
#   'o55714',
#   'o55715',
#   'o55717',
#   'o55718',
#   'o55719',
#   'o55722',
#   'o55723',
#   'o55724',
#   'o55725',
#   'o55726',
#   'o55727',
#   'o55728',
#   'o55731',
#   'o55734',
#   'o55735',
#   'o55736',
#   'o55737',
#   'o55738',
#   'o55739',
#   'o55740',
#   'o55741',
#   'o55743',
#   'o55744',
#   'o55745',
#   'o55746',
#   'o55747',
#   'o65352',
#   'o70456',
#   'o73557',
#   'o77642',
#   'o95229',
#   'o96436',
#   'p08105',
#   'p0a3e6',
#   'p0a3e7',
#   'p0ac51',
#   'p0ac52',
#   'p0c664',
#   'p0c9e9',
#   'p0c9f0',
#   'p0c9f1',
#   'p0c9f2',
#   'p0c9f3',
#   'p0c9f4',
#   'p0c9f5',
#   'p0c9f6',
#   'p0c9f7',
#   'p0c9f8',
#   'p0c9f9',
#   'p0c9g0',
#   'p0c9g1',
#   'p0c9g2',
#   'p0c9g3',
#   'p0c9g4',
#   'p0c9g5',
#   'p0c9g6',
#   'p0c9g7',
#   'p0c9g8',
#   'p0c9g9',
#   'p0c9h0',
#   'p0c9h1',
#   'p0c9h2',
#   'p0c9h3',
#   'p0c9h4',
#   'p0c9h5',
#   'p0c9h6',
#   'p0c9h7',
#   'p0c9h8',
#   'p0c9h9',
#   'p0c9i0',
#   'p0c9i1',
#   'p0c9i2',
#   'p0c9i3',
#   'p0c9i4',
#   'p0c9i5',
#   'p0c9i6',
#   'p0c9i7',
#   'p0c9i8',
#   'p0c9i9',
#   'p0c9j0',
#   'p0c9j1',
#   'p0c9j2',
#   'p0c9j3',
#   'p0c9j4',
#   'p0c9j5',
#   'p0c9j6',
#   'p0c9j7',
#   'p0c9j8',
#   'p0c9j9',
#   'p0c9k0',
#   'p0c9k1',
#   'p0c9k2',
#   'p0c9k3',
#   'p13744',
#   'p13813',
#   'p15711',
#   'p18541',
#   'p18557',
#   'p18558',
#   'p18559',
#   'p18560',
#   'p19084',
#   'p19325',
#   'p19326',
#   'p21215',
#   'p21541',
#   'p27348',
#   'p29305',
#   'p29306',
#   'p29310',
#   'p29361',
#   'p31946',
#   'p31947',
#   'p32234',
#   'p35213',
#   'p41932',
#   'p42643',
#   'p42644',
#   'p42645',
#   'p42648',
#   'p42649',
#   'p42650',
#   'p42652',
#   'p42653',
#   'p42654',
#   'p46077',
#   'p48347',
#   'p48348',
#   'p48349',
#   'p49106',
#   'p52908',
#   'p54479',
#   'p54632',
#   'p61981',
#   'p61982',
#   'p61983',
#   'p62258',
#   'p62259',
#   'p62260',
#   'p62261',
#   'p62262',
#   'p63101',
#   'p63102',
#   'p63103',
#   'p63104',
#   'p67470',
#   'p67471',
#   'p68250',
#   'p68251',
#   'p68252',
#   'p68253',
#   'p68254',
#   'p68255',
#   'p68509',
#   'p68510',
#   'p68511',
#   'p68744',
#   'p80438',
#   'p81928',
#   'p83004',
#   'p83010',
#   'p83011',
#   'p85938',
#   'p85939',
#   'p85941',
#   'p85942',
#   'p92177',
#   'p93206',
#   'p93207',
#   'p93208',
#   'p93209',
#   'p93210',
#   'p93211',
#   'p93212',
#   'p93213',
#   'p93214',
#   'p93342',
#   'p93343',
#   'p93784',
#   'p98168',
#   'p98169',
#   'q01525',
#   'q01526',
#   'q04584',
#   'q04917',
#   'q05349',
#   'q06967',
#   'q0ij01',
#   'q0t0l8',
#   'q0va45',
#   'q0vc36',
#   'q15942',
#   'q196t4',
#   'q196t5',
#   'q196t6',
#   'q196t7',
#   'q196t8',
#   'q196u1',
#   'q196u2',
#   'q196u3',
#   'q196u4',
#   'q196u6',
#   'q196v0',
#   'q196v2',
#   'q196v7',
#   'q196v8',
#   'q196w5',
#   'q196w8',
#   'q196x1',
#   'q196x8',
#   'q196x9',
#   'q196y0',
#   'q196y3',
#   'q196y5',
#   'q196y7',
#   'q196y8',
#   'q196z6',
#   'q196z8',
#   'q197a3',
#   'q197a6',
#   'q197a7',
#   'q197b1',
#   'q197b5',
#   'q197b6',
#   'q197c0',
#   'q197c3',
#   'q197c8',
#   'q197d0',
#   'q197d2',
#   'q197d5',
#   'q197d7',
#   'q197d8',
#   'q197e7',
#   'q197e9',
#   'q197f2',
#   'q197f3',
#   'q197f5',
#   'q197f7',
#   'q197f8',
#   'q1hr36',
#   'q20655',
#   'q24902',
#   'q26537',
#   'q26540',
#   'q27ye2',
#   'q27ye6',
#   'q2f637',
#   'q2qgd7',
#   'q2r1d5',
#   'q2r2w2',
#   'q2tbh8',
#   'q32bu5',
#   'q39757',
#   'q3b4g1',
#   'q3szi4',
#   'q3ufs0',
#   'q3yxk1',
#   'q41418',
#   'q43470',
#   'q43495',
#   'q43643',
#   'q4r572',
#   'q4u9m9',
#   'q4v8c2',
#   'q52m98',
#   'q57js2',
#   'q5f3w6',
#   'q5pmu9',
#   'q5qnb8',
#   'q5r651',
#   'q5ra78',
#   'q5rc20',
#   'q5rfj2',
#   'q5rfm4',
#   'q5ssh7',
#   'q5tyq1',
#   'q5xgc8',
#   'q5zkc9',
#   'q5zlq6',
#   'q5zmd1',
#   'q5zmt0',
#   'q621j7',
#   'q62523',
#   'q65209',
#   'q65210',
#   'q67475',
#   'q6eup4',
#   'q6gzm7',
#   'q6gzm8',
#   'q6gzm9',
#   'q6gzn0',
#   'q6gzn1',
#   'q6gzn2',
#   'q6gzn3',
#   'q6gzn6',
#   'q6gzn7',
#   'q6gzn8',
#   'q6gzn9',
#   'q6gzp1',
#   'q6gzp4',
#   'q6gzp6',
#   'q6gzp7',
#   'q6gzp8',
#   'q6gzp9',
#   'q6gzq0',
#   'q6gzq1',
#   'q6gzq2',
#   'q6gzq3',
#   'q6gzq4',
#   'q6gzq5',
#   'q6gzq6',
#   'q6gzq7',
#   'q6gzq9',
#   'q6gzr0',
#   'q6gzr1',
#   'q6gzr4',
#   'q6gzr6',
#   'q6gzr7',
#   'q6gzr8',
#   'q6gzr9',
#   'q6gzs1',
#   'q6gzs2',
#   'q6gzs3',
#   'q6gzs4',
#   'q6gzs5',
#   'q6gzs6',
#   'q6gzs7',
#   'q6gzs8',
#   'q6gzs9',
#   'q6gzt0',
#   'q6gzt1',
#   'q6gzt2',
#   'q6gzt3',
#   'q6gzt4',
#   'q6gzt5',
#   'q6gzt6',
#   'q6gzt7',
#   'q6gzt9',
#   'q6gzu0',
#   'q6gzu1',
#   'q6gzu2',
#   'q6gzu3',
#   'q6gzu4',
#   'q6gzu5',
#   'q6gzu6',
#   'q6gzu7',
#   'q6gzu8',
#   'q6gzu9',
#   'q6gzv1',
#   'q6gzv2',
#   'q6gzv4',
#   'q6gzv5',
#   'q6gzv6',
#   'q6gzv7',
#   'q6gzv8',
#   'q6gzw0',
#   'q6gzw1',
#   'q6gzw2',
#   'q6gzw3',
#   'q6gzw4',
#   'q6gzw5',
#   'q6gzw6',
#   'q6gzw8',
#   'q6gzw9',
#   'q6gzx0',
#   'q6gzx1',
#   'q6gzx2',
#   'q6gzx3',
#   'q6gzx4',
#   'q6irm9',
#   'q6iuf9',
#   'q6ivu5',
#   'q6kaq7',
#   'q6p4z5',
#   'q6q6x0',
#   'q6rss3',
#   'q6uy62',
#   'q6uy71',
#   'q6v4h0',
#   'q6wrx3',
#   'q6zkc0',
#   'q76n59',
#   'q7ubj3',
#   'q7xte8',
#   'q84j55',
#   'q88470',
#   'q8c8v1',
#   'q8dry7',
#   'q8enq1',
#   'q8gbw6',
#   'q8gsp8',
#   'q8iyh5',
#   'q8mm75',
#   'q8mua4',
#   'q8p8z6',
#   'q8pkq5',
#   'q8r060',
#   'q8sw28',
#   'q8vil3',
#   'q91896',
#   'q91g04',
#   'q91g40',
#   'q91g50',
#   'q91g54',
#   'q91g55',
#   'q91g56',
#   'q91g57',
#   'q91g63',
#   'q91g65',
#   'q91g67',
#   'q91g70',
#   'q91g85',
#   'q91g88',
#   'q926d8',
#   'q95xp9',
#   'q96299',
#   'q96300',
#   'q96450',
#   'q96451',
#   'q96452',
#   'q96453',
#   'q9c0d3',
#   'q9c5w6',
#   'q9cqu5',
#   'q9cqv8',
#   'q9g058',
#   'q9gt24',
#   'q9h900',
#   'q9jx23',
#   'q9k1h6',
#   'q9s9z8',
#   'q9sp07',
#   'q9u408',
#   'q9utc0',
#   'q9va00',
#   'q9w4x9',
#   'q9xda6',
#   'q9xfm4',
#   'q9xhp0'},
#  'Union': {'a0jmz3',
#   'a0pj23',
#   'a1krk6',
#   'a2bfl2',
#   'a2ce44',
#   'a4k2u9',
#   'a4se48',
#   'a4seb1_3',
#   'a4wei1',
#   'a5h447',
#   'a5wwb6',
#   'a6qm04',
#   'a9jr22',
#   'a9jr44',
#   'a9mpx1',
#   'a9n5w7',
#   'a9n5w7_a',
#   'b0blk0',
#   'b0blk7',
#   'b0blk9',
#   'b1hyt6',
#   'b1lf36',
#   'b1lf36_2',
#   'b2c4j2',
#   'b2fm90',
#   'b2mw50',
#   'b2zdy1',
#   'b4spv6',
#   'b4t660',
#   'b4ti40',
#   'b4tvs2',
#   'b5bg02',
#   'b5bg02_c',
#   'b5f683',
#   'b5fv58',
#   'b5qz27',
#   'b5ree9',
#   'b6i411',
#   'b6i411_1',
#   'b7lqb7',
#   'c0pyw1',
#   'c0pyw1_b',
#   'g5eem5',
#   'o05839',
#   'o23878',
#   'o23880',
#   'o42766',
#   'o43149',
#   'o43264',
#   'o44218',
#   'o44219',
#   'o48626',
#   'o49995',
#   'o49996',
#   'o49997',
#   'o49998',
#   'o54692',
#   'o55703',
#   'o55704',
#   'o55705',
#   'o55706',
#   'o55709',
#   'o55710',
#   'o55713',
#   'o55714',
#   'o55715',
#   'o55717',
#   'o55718',
#   'o55719',
#   'o55722',
#   'o55723',
#   'o55724',
#   'o55725',
#   'o55726',
#   'o55727',
#   'o55728',
#   'o55731',
#   'o55734',
#   'o55735',
#   'o55736',
#   'o55737',
#   'o55738',
#   'o55739',
#   'o55740',
#   'o55741',
#   'o55743',
#   'o55744',
#   'o55745',
#   'o55746',
#   'o55747',
#   'o65352',
#   'o70456',
#   'o73557',
#   'o77642',
#   'o95229',
#   'o96436',
#   'p08105',
#   'p0a3e6',
#   'p0a3e7',
#   'p0ac51',
#   'p0ac52',
#   'p0c664',
#   'p0c9e9',
#   'p0c9f0',
#   'p0c9f1',
#   'p0c9f2',
#   'p0c9f3',
#   'p0c9f4',
#   'p0c9f5',
#   'p0c9f6',
#   'p0c9f7',
#   'p0c9f8',
#   'p0c9f9',
#   'p0c9g0',
#   'p0c9g1',
#   'p0c9g2',
#   'p0c9g3',
#   'p0c9g4',
#   'p0c9g5',
#   'p0c9g6',
#   'p0c9g7',
#   'p0c9g8',
#   'p0c9g9',
#   'p0c9h0',
#   'p0c9h1',
#   'p0c9h2',
#   'p0c9h3',
#   'p0c9h4',
#   'p0c9h5',
#   'p0c9h6',
#   'p0c9h7',
#   'p0c9h8',
#   'p0c9h9',
#   'p0c9i0',
#   'p0c9i1',
#   'p0c9i2',
#   'p0c9i3',
#   'p0c9i4',
#   'p0c9i5',
#   'p0c9i6',
#   'p0c9i7',
#   'p0c9i8',
#   'p0c9i9',
#   'p0c9j0',
#   'p0c9j1',
#   'p0c9j2',
#   'p0c9j3',
#   'p0c9j4',
#   'p0c9j5',
#   'p0c9j6',
#   'p0c9j7',
#   'p0c9j8',
#   'p0c9j9',
#   'p0c9k0',
#   'p0c9k1',
#   'p0c9k2',
#   'p0c9k3',
#   'p13744',
#   'p13813',
#   'p15711',
#   'p18541',
#   'p18557',
#   'p18558',
#   'p18559',
#   'p18560',
#   'p19084',
#   'p19325',
#   'p19326',
#   'p21215',
#   'p21541',
#   'p27348',
#   'p29305',
#   'p29306',
#   'p29310',
#   'p29361',
#   'p31946',
#   'p31947',
#   'p32234',
#   'p35213',
#   'p41932',
#   'p42643',
#   'p42644',
#   'p42645',
#   'p42648',
#   'p42649',
#   'p42650',
#   'p42652',
#   'p42653',
#   'p42654',
#   'p46077',
#   'p48347',
#   'p48348',
#   'p48349',
#   'p49106',
#   'p52908',
#   'p54479',
#   'p54632',
#   'p61981',
#   'p61982',
#   'p61983',
#   'p62258',
#   'p62259',
#   'p62260',
#   'p62261',
#   'p62262',
#   'p63101',
#   'p63102',
#   'p63103',
#   'p63104',
#   'p67470',
#   'p67471',
#   'p68250',
#   'p68251',
#   'p68252',
#   'p68253',
#   'p68254',
#   'p68255',
#   'p68509',
#   'p68510',
#   'p68511',
#   'p68744',
#   'p80438',
#   'p81928',
#   'p83004',
#   'p83010',
#   'p83011',
#   'p85938',
#   'p85939',
#   'p85941',
#   'p85942',
#   'p92177',
#   'p93206',
#   'p93207',
#   'p93208',
#   'p93209',
#   'p93210',
#   'p93211',
#   'p93212',
#   'p93213',
#   'p93214',
#   'p93342',
#   'p93343',
#   'p93784',
#   'p98168',
#   'p98169',
#   'q01525',
#   'q01526',
#   'q04584',
#   'q04917',
#   'q05349',
#   'q06967',
#   'q0ij01',
#   'q0t0l8',
#   'q0va45',
#   'q0vc36',
#   'q15942',
#   'q196t4',
#   'q196t5',
#   'q196t6',
#   'q196t7',
#   'q196t8',
#   'q196u1',
#   'q196u2',
#   'q196u3',
#   'q196u4',
#   'q196u6',
#   'q196v0',
#   'q196v2',
#   'q196v7',
#   'q196v8',
#   'q196w5',
#   'q196w8',
#   'q196x1',
#   'q196x8',
#   'q196x9',
#   'q196y0',
#   'q196y3',
#   'q196y5',
#   'q196y7',
#   'q196y8',
#   'q196z6',
#   'q196z8',
#   'q197a3',
#   'q197a6',
#   'q197a7',
#   'q197b1',
#   'q197b5',
#   'q197b6',
#   'q197c0',
#   'q197c3',
#   'q197c8',
#   'q197d0',
#   'q197d2',
#   'q197d5',
#   'q197d7',
#   'q197d8',
#   'q197e7',
#   'q197e9',
#   'q197f2',
#   'q197f3',
#   'q197f5',
#   'q197f7',
#   'q197f8',
#   'q1hr36',
#   'q20655',
#   'q24902',
#   'q26537',
#   'q26540',
#   'q27ye2',
#   'q27ye6',
#   'q2f637',
#   'q2qgd7',
#   'q2r1d5',
#   'q2r2w2',
#   'q2tbh8',
#   'q32bu5',
#   'q39757',
#   'q3b4g1',
#   'q3szi4',
#   'q3ufs0',
#   'q3yxk1',
#   'q41418',
#   'q43470',
#   'q43495',
#   'q43643',
#   'q4r572',
#   'q4u9m9',
#   'q4v8c2',
#   'q52m98',
#   'q57js2',
#   'q5f3w6',
#   'q5pmu9',
#   'q5qnb8',
#   'q5r651',
#   'q5ra78',
#   'q5rc20',
#   'q5rfj2',
#   'q5rfm4',
#   'q5ssh7',
#   'q5tyq1',
#   'q5xgc8',
#   'q5zkc9',
#   'q5zlq6',
#   'q5zmd1',
#   'q5zmt0',
#   'q621j7',
#   'q62523',
#   'q65209',
#   'q65210',
#   'q67475',
#   'q6eup4',
#   'q6gzm7',
#   'q6gzm8',
#   'q6gzm9',
#   'q6gzn0',
#   'q6gzn1',
#   'q6gzn2',
#   'q6gzn3',
#   'q6gzn6',
#   'q6gzn7',
#   'q6gzn8',
#   'q6gzn9',
#   'q6gzp1',
#   'q6gzp4',
#   'q6gzp6',
#   'q6gzp7',
#   'q6gzp8',
#   'q6gzp9',
#   'q6gzq0',
#   'q6gzq1',
#   'q6gzq2',
#   'q6gzq3',
#   'q6gzq4',
#   'q6gzq5',
#   'q6gzq6',
#   'q6gzq7',
#   'q6gzq9',
#   'q6gzr0',
#   'q6gzr1',
#   'q6gzr4',
#   'q6gzr6',
#   'q6gzr7',
#   'q6gzr8',
#   'q6gzr9',
#   'q6gzs1',
#   'q6gzs2',
#   'q6gzs3',
#   'q6gzs4',
#   'q6gzs5',
#   'q6gzs6',
#   'q6gzs7',
#   'q6gzs8',
#   'q6gzs9',
#   'q6gzt0',
#   'q6gzt1',
#   'q6gzt2',
#   'q6gzt3',
#   'q6gzt4',
#   'q6gzt5',
#   'q6gzt6',
#   'q6gzt7',
#   'q6gzt9',
#   'q6gzu0',
#   'q6gzu1',
#   'q6gzu2',
#   'q6gzu3',
#   'q6gzu4',
#   'q6gzu5',
#   'q6gzu6',
#   'q6gzu7',
#   'q6gzu8',
#   'q6gzu9',
#   'q6gzv1',
#   'q6gzv2',
#   'q6gzv4',
#   'q6gzv5',
#   'q6gzv6',
#   'q6gzv7',
#   'q6gzv8',
#   'q6gzw0',
#   'q6gzw1',
#   'q6gzw2',
#   'q6gzw3',
#   'q6gzw4',
#   'q6gzw5',
#   'q6gzw6',
#   'q6gzw8',
#   'q6gzw9',
#   'q6gzx0',
#   'q6gzx1',
#   'q6gzx2',
#   'q6gzx3',
#   'q6gzx4',
#   'q6irm9',
#   'q6iuf9',
#   'q6ivu5',
#   'q6kaq7',
#   'q6p4z5',
#   'q6q6x0',
#   'q6rss3',
#   'q6uy62',
#   'q6uy71',
#   'q6v4h0',
#   'q6wrx3',
#   'q6zkc0',
#   'q76n59',
#   'q7ubj3',
#   'q7xte8',
#   'q84j55',
#   'q88470',
#   'q8c8v1',
#   'q8dry7',
#   'q8enq1',
#   'q8gbw6',
#   'q8gsp8',
#   'q8iyh5',
#   'q8mm75',
#   'q8mua4',
#   'q8p8z6',
#   'q8pkq5',
#   'q8r060',
#   'q8sw28',
#   'q8vil3',
#   'q91896',
#   'q91g04',
#   'q91g40',
#   'q91g50',
#   'q91g54',
#   'q91g55',
#   'q91g56',
#   'q91g57',
#   'q91g63',
#   'q91g65',
#   'q91g67',
#   'q91g70',
#   'q91g85',
#   'q91g88',
#   'q926d8',
#   'q95xp9',
#   'q96299',
#   'q96300',
#   'q96450',
#   'q96451',
#   'q96452',
#   'q96453',
#   'q9c0d3',
#   'q9c5w6',
#   'q9cqu5',
#   'q9cqv8',
#   'q9g058',
#   'q9gt24',
#   'q9h900',
#   'q9jx23',
#   'q9k1h6',
#   'q9s9z8',
#   'q9sp07',
#   'q9u408',
#   'q9utc0',
#   'q9va00',
#   'q9w4x9',
#   'q9xda6',
#   'q9xfm4',
#   'q9xhp0'},
#  'Frequency': {'b4t660': 3,
#   'q6gzq4': 3,
#   'p0c9j9': 3,
#   'p83010': 3,
#   'q8pkq5': 3,
#   'q197c8': 3,
#   'q2r1d5': 3,
#   'q6gzq3': 3,
#   'p41932': 3,
#   'q6gzq9': 3,
#   'p0c9g5': 3,
#   'q197b1': 3,
#   'q9c0d3': 3,
#   'q197f2': 3,
#   'q6gzq6': 3,
#   'q6gzu8': 3,
#   'a5wwb6': 3,
#   'p93207': 3,
#   'q9w4x9': 3,
#   'q6gzr0': 3,
#   'q6gzn0': 3,
#   'q6gzq7': 3,
#   'q196v8': 3,
#   'p0c9j2': 3,
#   'a9mpx1': 3,
#   'p0c9f9': 3,
#   'q8enq1': 3,
#   'q5rfm4': 3,
#   'a6qm04': 3,
#   'p29361': 3,
#   'q196u6': 3,
#   'q6gzu2': 3,
#   'q9cqv8': 3,
#   'b1lf36': 2,
#   'q6gzw9': 3,
#   'q96299': 3,
#   'q6uy62': 3,
#   'q197f3': 3,
#   'q196y8': 3,
#   'q04584': 3,
#   'p21541': 3,
#   'o55734': 3,
#   'o55740': 3,
#   'q91g50': 3,
#   'b0blk0': 3,
#   'q6gzn6': 3,
#   'o55739': 3,
#   'q9s9z8': 3,
#   'p85941': 3,
#   'q3ufs0': 3,
#   'q9sp07': 3,
#   'p0c9i0': 3,
#   'q2r2w2': 3,
#   'b5f683': 3,
#   'q96452': 3,
#   'p0c9i8': 3,
#   'p29310': 3,
#   'q6gzt9': 3,
#   'o55713': 3,
#   'q196x1': 3,
#   'q5f3w6': 3,
#   'q9g058': 3,
#   'a4k2u9': 3,
#   'q6gzw5': 3,
#   'p0c9g7': 3,
#   'p32234': 3,
#   'o55718': 3,
#   'p81928': 3,
#   'p0c9j6': 3,
#   'q6gzm8': 3,
#   'p0c9j4': 3,
#   'q6eup4': 3,
#   'b5bg02': 2,
#   'p0a3e6': 3,
#   'q24902': 3,
#   'q6gzr7': 3,
#   'q197b6': 3,
#   'q196w5': 3,
#   'q96300': 3,
#   'q196u1': 3,
#   'q196z8': 3,
#   'q9xhp0': 3,
#   'c0pyw1': 2,
#   'q26540': 3,
#   'b6i411': 2,
#   'q197f8': 3,
#   'o55745': 3,
#   'p0c9i4': 3,
#   'p54632': 3,
#   'o55706': 3,
#   'q2f637': 3,
#   'q6gzq0': 3,
#   'p68254': 3,
#   'p68509': 3,
#   'q6gzn2': 3,
#   'q6gzn8': 3,
#   'q8gbw6': 3,
#   'q91g04': 3,
#   'q43643': 3,
#   'q20655': 3,
#   'p68511': 3,
#   'p85938': 3,
#   'q6gzu9': 3,
#   'p0c9j8': 3,
#   'p13744': 3,
#   'o55736': 3,
#   'p0c9i9': 3,
#   'q6gzu7': 3,
#   'p0c9e9': 3,
#   'p0c9i5': 3,
#   'p63102': 3,
#   'q05349': 3,
#   'o49995': 3,
#   'q196y0': 3,
#   'p98169': 3,
#   'q9gt24': 3,
#   'q196t5': 3,
#   'p0c9h4': 3,
#   'p68253': 3,
#   'q9jx23': 3,
#   'o49996': 3,
#   'o55737': 3,
#   'b2fm90': 3,
#   'q196t7': 3,
#   'q6gzw6': 3,
#   'p42648': 3,
#   'p08105': 3,
#   'q6gzs2': 3,
#   'p0c9k3': 3,
#   'p19325': 3,
#   'p0c9j5': 3,
#   'o55714': 3,
#   'q6gzs5': 3,
#   'p93343': 3,
#   'q3szi4': 3,
#   'p31947': 3,
#   'q197c3': 3,
#   'p93211': 3,
#   'q8vil3': 3,
#   'q6gzn1': 3,
#   'q6gzx2': 3,
#   'q8gsp8': 3,
#   'q197a3': 3,
#   'q197d7': 3,
#   'q6gzu4': 3,
#   'p42649': 3,
#   'o55709': 3,
#   'q196v7': 3,
#   'q6gzx3': 3,
#   'q6gzt2': 3,
#   'b4ti40': 3,
#   'q04917': 3,
#   'q65210': 3,
#   'q6gzm7': 3,
#   'o55735': 3,
#   'q6gzs8': 3,
#   'q5ra78': 3,
#   'q6gzv8': 3,
#   'q196t6': 3,
#   'q6gzs3': 3,
#   'p63104': 3,
#   'o23880': 3,
#   'q5zkc9': 3,
#   'q196y7': 3,
#   'q57js2': 3,
#   'q6gzn7': 3,
#   'q6gzp6': 3,
#   'q8c8v1': 3,
#   'q8r060': 3,
#   'p0c9k1': 3,
#   'q7xte8': 3,
#   'q88470': 3,
#   'a4wei1': 2,
#   'p13813': 3,
#   'q196t4': 3,
#   'q197d8': 3,
#   'q6gzv5': 3,
#   'q196v0': 3,
#   'p0c9i7': 3,
#   'q0ij01': 3,
#   'q41418': 3,
#   'a4seb1_3': 1,
#   'q7ubj3': 3,
#   'q6ivu5': 3,
#   'q196v2': 3,
#   'q91g54': 3,
#   'p0c9f8': 3,
#   'q6gzx1': 3,
#   'q196u4': 3,
#   'q6gzw4': 3,
#   'p0ac51': 3,
#   'q95xp9': 3,
#   'o23878': 3,
#   'q15942': 3,
#   'q5zmt0': 3,
#   'q01526': 3,
#   'q62523': 3,
#   'q6gzv1': 3,
#   'q197a6': 3,
#   'p0c9g0': 3,
#   'o55703': 3,
#   'p0c9h6': 3,
#   'q32bu5': 3,
#   'q6gzn9': 3,
#   'q6gzt4': 3,
#   'o55744': 3,
#   'p62258': 3,
#   'q6gzu5': 3,
#   'p0c9g1': 3,
#   'o77642': 3,
#   'q5tyq1': 3,
#   'p0c9h2': 3,
#   'q9u408': 3,
#   'p0c9g4': 3,
#   'q9k1h6': 3,
#   'p0c9g3': 3,
#   'q5r651': 3,
#   'q8sw28': 3,
#   'p93214': 3,
#   'p0c9f7': 3,
#   'q6gzv4': 3,
#   'p18558': 3,
#   'a2bfl2': 3,
#   'q197d2': 3,
#   'q6zkc0': 3,
#   'p0c9h8': 3,
#   'q196t8': 3,
#   'p68251': 3,
#   'p62262': 3,
#   'p0c9j0': 3,
#   'p27348': 3,
#   'q6q6x0': 3,
#   'b2zdy1': 3,
#   'p63103': 3,
#   'o43264': 3,
#   'p0c9g6': 3,
#   'p0c9g9': 3,
#   'q6gzu6': 3,
#   'p46077': 3,
#   'q91g85': 3,
#   'p68255': 3,
#   'q6gzq1': 3,
#   'a9n5w7_a': 1,
#   'q3b4g1': 3,
#   'p19326': 3,
#   'p92177': 3,
#   'q91g55': 3,
#   'q91g57': 3,
#   'o55746': 3,
#   'q6uy71': 3,
#   'o44219': 3,
#   'g5eem5': 3,
#   'p0c9i6': 3,
#   'p62260': 3,
#   'p0c9h9': 3,
#   'q6wrx3': 3,
#   'p93209': 3,
#   'b4tvs2': 3,
#   'b4spv6': 3,
#   'p93212': 3,
#   'q6gzx0': 3,
#   'q43495': 3,
#   'q196u3': 3,
#   'p19084': 3,
#   'p68510': 3,
#   'p93208': 3,
#   'p62259': 3,
#   'q9h900': 3,
#   'p93784': 3,
#   'q197c0': 3,
#   'q2qgd7': 3,
#   'q196w8': 3,
#   'p29305': 3,
#   'b5ree9': 3,
#   'q5zlq6': 3,
#   'o55723': 3,
#   'o49998': 3,
#   'q196x9': 3,
#   'q6gzp4': 3,
#   'p18557': 3,
#   'q6gzq5': 3,
#   'b6i411_1': 1,
#   'q6gzt6': 3,
#   'q6gzr8': 3,
#   'o55704': 3,
#   'p42652': 3,
#   'o48626': 3,
#   'p68252': 3,
#   'q5pmu9': 3,
#   'p67471': 3,
#   'a1krk6': 3,
#   'p68250': 3,
#   'q9va00': 3,
#   'q91g88': 3,
#   'p93342': 3,
#   'p18560': 3,
#   'p0c9h0': 3,
#   'p0c9i1': 3,
#   'o96436': 3,
#   'o55710': 3,
#   'p0c9j1': 3,
#   'o44218': 3,
#   'p0c9h7': 3,
#   'q6rss3': 3,
#   'q06967': 3,
#   'q196z6': 3,
#   'q5ssh7': 3,
#   'o55715': 3,
#   'q6gzp8': 3,
#   'q9cqu5': 3,
#   'q8mm75': 3,
#   'q5rc20': 3,
#   'q8p8z6': 3,
#   'q197f7': 3,
#   'p0c9h3': 3,
#   'p48348': 3,
#   'q197d0': 3,
#   'b2mw50': 3,
#   'q96453': 3,
#   'q6gzx4': 3,
#   'a9n5w7': 2,
#   'p0c9f1': 3,
#   'p0c9f4': 3,
#   'p54479': 3,
#   'q197e9': 3,
#   'p0c9k2': 3,
#   'q6gzt7': 3,
#   'q91g56': 3,
#   'p0c9i2': 3,
#   'p42645': 3,
#   'p0c9k0': 3,
#   'p0c9f3': 3,
#   'q6gzr6': 3,
#   'q6gzq2': 3,
#   'p0c9j3': 3,
#   'q96451': 3,
#   'q67475': 3,
#   'q6gzs1': 3,
#   'q926d8': 3,
#   'q84j55': 3,
#   'p83011': 3,
#   'q8iyh5': 3,
#   'q197a7': 3,
#   'q9utc0': 3,
#   'q6gzw0': 3,
#   'q621j7': 3,
#   'p0c9g8': 3,
#   'q196u2': 3,
#   'p63101': 3,
#   'q96450': 3,
#   'q5zmd1': 3,
#   'q6gzn3': 3,
#   'p0c9f2': 3,
#   'p35213': 3,
#   'q8dry7': 3,
#   'q27ye6': 3,
#   'q6gzw2': 3,
#   'q197b5': 3,
#   'q6gzu1': 3,
#   'q91896': 3,
#   'p42643': 3,
#   'q196y3': 3,
#   'o70456': 3,
#   'q6gzr9': 3,
#   'q197e7': 3,
#   'q6irm9': 3,
#   'q91g40': 3,
#   'o55741': 3,
#   'q6gzp9': 3,
#   'q6gzm9': 3,
#   'a2ce44': 3,
#   'q4u9m9': 3,
#   'b0blk7': 3,
#   'p31946': 3,
#   'a4se48': 3,
#   'p0c9j7': 3,
#   'q6gzw3': 3,
#   'o55726': 3,
#   'q5rfj2': 3,
#   'p61983': 3,
#   'q76n59': 3,
#   'o55717': 3,
#   'q5xgc8': 3,
#   'p0c9h5': 3,
#   'p67470': 3,
#   'p29306': 3,
#   'p0c9f6': 3,
#   'o05839': 3,
#   'p0c9i3': 3,
#   'q6gzu0': 3,
#   'p0ac52': 3,
#   'q6v4h0': 3,
#   'q9c5w6': 3,
#   'q4v8c2': 3,
#   'c0pyw1_b': 1,
#   'o55705': 3,
#   'q6gzp7': 3,
#   'p61982': 3,
#   'p62261': 3,
#   'p42650': 3,
#   'b7lqb7': 3,
#   'p98168': 3,
#   'q6gzv2': 3,
#   'b1hyt6': 3,
#   'q6gzs9': 3,
#   'q5qnb8': 3,
#   'o42766': 3,
#   'p48347': 3,
#   'b5fv58': 3,
#   'q197f5': 3,
#   'q6gzu3': 3,
#   'q6gzt0': 3,
#   'o73557': 3,
#   'p83004': 3,
#   'q8mua4': 3,
#   'o55724': 3,
#   'o49997': 3,
#   'q01525': 3,
#   'p42653': 3,
#   'o43149': 3,
#   'o55743': 3,
#   'q43470': 3,
#   'q9xda6': 3,
#   'q91g65': 3,
#   'o95229': 3,
#   'q6gzr4': 3,
#   'p61981': 3,
#   'p15711': 3,
#   'q91g63': 3,
#   'q1hr36': 3,
#   'q6gzt3': 3,
#   'a0pj23': 3,
#   'q196x8': 3,
#   'p18541': 3,
#   'p68744': 3,
#   'q6gzw1': 3,
#   'o55728': 3,
#   'q6iuf9': 3,
#   'o54692': 3,
#   'b2c4j2': 3,
#   'p0c664': 3,
#   'q196y5': 3,
#   'o65352': 3,
#   'o55747': 3,
#   'q6gzs7': 3,
#   'b5qz27': 3,
#   'q6gzp1': 3,
#   'o55722': 3,
#   'p42654': 3,
#   'q9xfm4': 3,
#   'a0jmz3': 3,
#   'q197d5': 3,
#   'p18559': 3,
#   'b1lf36_2': 1,
#   'a9jr44': 3,
#   'p42644': 3,
#   'o55727': 3,
#   'p80438': 3,
#   'q6gzw8': 3,
#   'q0va45': 3,
#   'p52908': 3,
#   'q6gzv6': 3,
#   'o55731': 3,
#   'q2tbh8': 3,
#   'b0blk9': 3,
#   'a9jr22': 3,
#   'q27ye2': 3,
#   'q26537': 3,
#   'p93210': 3,
#   'p93206': 3,
#   'q6gzr1': 3,
#   'p0a3e7': 3,
#   'o55725': 3,
#   'p93213': 3,
#   'q6p4z5': 3,
#   'a5h447': 3,
#   'p0c9f5': 3,
#   'p0c9f0': 3,
#   'p0c9g2': 3,
#   'q6gzt1': 3,
#   'q6gzv7': 3,
#   'q39757': 3,
#   'p0c9h1': 3,
#   'p85942': 3,
#   'o55719': 3,
#   'q65209': 3,
#   'p49106': 3,
#   'q6kaq7': 3,
#   'q0vc36': 3,
#   'o55738': 3,
#   'q0t0l8': 3,
#   'q91g70': 3,
#   'q6gzt5': 3,
#   'q4r572': 3,
#   'q91g67': 3,
#   'p85939': 3,
#   'q6gzs4': 3,
#   'q52m98': 3,
#   'p21215': 3,
#   'p48349': 3,
#   'q3yxk1': 3,
#   'b5bg02_c': 1,
#   'q6gzs6': 3},
#  'Specificity': {'uniprot_sprot_sample.fasta': set(),
#   'uniprot_sprot_sample2.fasta': {'a4seb1_3', 'b1lf36_2', 'b6i411_1'},
#   'uniprot_sprot_sample3.fasta': {'a9n5w7_a', 'b5bg02_c', 'c0pyw1_b'}}}

# %%
info = compare_fasta_file_identifiers([
    "uniprot_sprot_sample.fasta",
    "uniprot_sprot_sample2.fasta",
    "uniprot_sprot_sample3.fasta"])

# %%
info.keys()
# Out:
# dict_keys(['Intersection', 'Union', 'Frequency', 'Specificity'])

# %%
[(k, type(info[k]), len(info[k])) for k in info.keys()]
# Out:
# [('Intersection', set, 491),
#  ('Union', set, 503),
#  ('Frequency', dict, 503),
#  ('Specificity', dict, 3)]
