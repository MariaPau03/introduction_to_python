# %%
# %load_ext autoreload
# %autoreload 2

# %%
from theory_S08 import Cup

# %%
type(Cup)
# Out:
# type

# %% [markdown]
# Create an instance of that class

# %%
c1 = Cup()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c1 = Cup()
#
# File ~/Desktop/Master/2nd TERM/PYT/S08/theory_S08.py:3, in Cup.__init__(self)
#       2 def __init__(self):
# ----> 3     self.__content = coffee
#
# NameError: name 'coffee' is not defined

# %% [markdown]
# the init funciton is always called when creating an instance

# %% [markdown]
# then define the atribtutes, and we know that because it contian self.somehting.

# %%
dir(c1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# The follwoing code is twhat is writen in the module:

# %%
class Cup():
    def __init__(self):
        self.content = None

    def fill(self, beverage):
        self.content = beverage

    def get_beverage(self):
        return self.content

# %%
c1.fill("water")
c1.get_beverage()
# Out:
# 'water'

# %%
c1.get_beverage()
# Out:
# 'water'

# %% [markdown]
# Let's try to make some of them private

# %%
class Cup():
    def __init__(self):
        self.__content = None

    def fill(self, beverage):
        self.content = beverage

    def get_beverage(self):
        return self.content

# %%
print(dir(c1))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'content', 'fill', 'get_beverage']

# %% [markdown]
# We still have fill and get_beverage, but now content has a different name, let's initilize to something else:

# %%
from theory_S08 import Protein

# %% [markdown]
# Create another class, hiding the attributes

# %%
class Protein():
    def __init__(self, identifier, sequence):
        self.__identifier = str(identifier)
        self.__seuqeunce = sequence

# %% [markdown]
# Class attribute: we want all the instances to have the same attribute

# %%
p1 = Protein("P1", "AAA")
p1

# %%
p1.get_mw
# Out:
# <bound method Protein.get_mw of <theory_S08.Protein object at 0x10478a120>>

# %%
p1.get_mw()
# Out:
# 30

# %%
Protein.aminoacid_mw
# Out:
# {'A': 10, 'B': 20}

# %% [markdown]
# Let's create another instance called p2

# %%
p2 = Protein("P2", "BBB")

# %%
p2.aminoacid_mw
# Out:
# {'A': 10, 'B': 20}

# %%
p2.aminoacid_mw is p1.aminoacid_mw
# Out:
# True

# %% [markdown]
# This returns if the id is matching, and in this case is true

# %%
p2.aminoacid_mw["A"] = 100

# %%
p2.aminoacid_mw
# Out:
# {'A': 100, 'B': 20}

# %% [markdown]
# in this case, changing the instance value will affect all instances

# %%
p1.aminoacid_mw
# Out:
# {'A': 100, 'B': 20}

# %%
from theory_S08 import Parent, Child

# %%
dir(Child)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# Create an instance of this classs

# %%
parent = Parent("AAA")

# %% [markdown]
# child inherits everything from superclass or parents

# %%
c = Child("BBB")

# %%
c.name
# Out:
# 'BBB'

# %%
parent.print_name()
# Out:
# I am the parent and my name is AAA

# %%
c.print_name()
# Out:
# I am the parent and my name is BBB

# %% [markdown]
# if we want to create a child attribute that the parent does not have:

# %% [markdown]
# put two parameters becasue we have added to age:

# %%
class Parent: #the parent class does not have ()
    def __init__(self, name):
        self.name = name
    
    def print_name(self): #create a method
        print(f"I am the parent and my name is {self.name}")

class Child(Parent): #the sub class has ()!!!!

    def __init__(self, name, age):
        self.age = age #unique attriubte of the child
        #we can access the super init funciton of the suepr class like this:
        super().__init__(name)

    print(f"I am the child and my name is {self.name}")

# %%
c = Child("BBB", 10)
c.name
c.age
# Out:
# 10
