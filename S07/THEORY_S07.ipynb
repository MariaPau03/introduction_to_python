# %% [markdown]
# First create the CLASS (is a template)

# %%
class Student():
    pass
import importlib
dir(importlib)
# Out:
# ['_RELOADING',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_abc',
#  '_bootstrap',
#  '_bootstrap_external',
#  '_imp',
#  '_pack_uint32',
#  '_unpack_uint32',
#  'abc',
#  'import_module',
#  'invalidate_caches',
#  'machinery',
#  'metadata',
#  'reload',
#  'sys',
#  'util']

# %%
type(importlib.reload)
# Out:
# function

# %%
import student

# %% [markdown]
# every time an instance of a class is created --> __init__

# %%
dir(student)
# Out:
# ['Student',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %%
from student import Student

# %% [markdown]
# The following code is the INSTANCE, which is a real object created from that class

# %%
student.Student()
# Out:
# Student object created

# %%
student.Student("Mery")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 student.Student("Mery")
#
# TypeError: Student.__init__() takes 1 positional argument but 2 were given

# %%
import importlib
import student
importlib.reload(student)
# Out:
# <module 'student' from '/Users/mariapaupijoan/Desktop/Master/2nd TERM/PYT/S07/student.py'>

# %% [markdown]
# Creaation of intances:

# %%
s = student.Student("Maria", "Pau", "u269315")
# Out:
# Student object created

# %%
s.name
# Out:
# 'Maria'

# %% [markdown]
# from the module we import the Student class

# %% [markdown]
# when we create an instance of the class, we see the code we have puted

# %%
import importlib
import student
importlib.reload(student)
# Out:
# <module 'student' from '/Users/mariapaupijoan/Desktop/Master/2nd TERM/PYT/S07/student.py'>

# %%
s = student.Student("Maria", "Pau", "u269315")

# %%
dir(s)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_subject',
#  'get_nie',
#  'name',
#  'nie',
#  'subjects',
#  'surname']

# %%
s.nie
# Out:
# 'u269315'

# %%
s.subjects
# Out:
# []

# %%
s.add_subject("PYT")

# %%
s.subjects
# Out:
# ['PYT']

# %% [markdown]
# "__init__"is a special function that runs automatically when you create a new object (instance) from a class. It is called the constructor.
# It is used to initialize the object’s data. per donar valors a l'objecte!!!

# %%
def __init__(self, name, surname, NIE):
    self.name = name
    self.surname = surname
    self.NIE = NIE
    self.subjects = []

# %% [markdown]
# Self means save this object in this instancE. Python uses it to know which object is working with
