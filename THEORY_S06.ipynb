# %%
import sys

# %%
print(sys.path)
# Out:
# ['/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python314.zip', '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14', '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14/lib-dynload', '', '/Users/mariapaupijoan/.local/lib/python3.14/site-packages', '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14/site-packages']

# %%
sys.path
# Out:
# ['/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python314.zip',
#  '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14',
#  '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14/lib-dynload',
#  '',
#  '/Users/mariapaupijoan/.local/lib/python3.14/site-packages',
#  '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14/site-packages']

# %% [markdown]
# when creating a module and putting inside a function, then in another python file i say import the first module, the code inside the first file will act inside the second one.

# %%
sys.path.append("home/MariaPau/Documents")

# %% [markdown]
# When creating a module, import it in a folder in sys.path which has been not created yet.

# %% [markdown]
# dir() --> __builtins__ moduel are located most of the funcitones that we have been using

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# See the names of math variable in the namespace

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %% [markdown]
# Import something as something

# %%
import math as m

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %% [markdown]
# The m letter will appear when doing dir(math). Same module, but with another name.

# %% [markdown]
# if two objects have the same ID, they are the same. Everything in python is an object!

# %%
id(math)
# Out:
# 4382821968

# %%
id(m)
# Out:
# 4382821968

# %%
from math import pi

# %%
dir() #see what we have got in my namespace
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_11',
#  '_12',
#  '_14',
#  '_5',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'm',
#  'math',
#  'open',
#  'pi',
#  'quit',
#  'sys']

# %% [markdown]
# If we import everything from math import * is better to import the only thing you want to import!!. eVERYTHING THAT WAS IN MY MATH MODUEL, i can put it in my namespace.

# %% [markdown]
# #see where is my math module

# %%
import math

# %%
math.__file__
# Out:
# '/Users/mariapaupijoan/miniconda3/envs/pyt/lib/python3.14/lib-dynload/math.cpython-314-darwin.so'

# %% [markdown]
# want to check in what actual file is this math module write, we can use this __file__ atttribute

# %%
math.__doc__
# Out:
# 'This module provides access to the mathematical functions\ndefined by the C standard.'

# %% [markdown]
# access to the compiled c library

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.14/library/math.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
# ...

# %%
__name__
# Out:
# '__main__'

# %%
math.__name__
# Out:
# 'math'

# %% [markdown]
# tells you the name of the module

# %% [markdown]
# To call a function in another file to put it in the current file:

# %%
if __name__ == "__main__":
    my_function()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 if __name__ == "__main__":
# ----> 2     my_function()
#
# NameError: name 'my_function' is not defined

# %% [markdown]
# we have a random module:

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.uniform(1,10)
# Out:
# 7.887615514696604

# %% [markdown]
# things that interact with our operating system

# %%
import os

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EVTONLY',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_FSYNC',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NOFOLLOW_ANY',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYMLINK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_SPAWN_CLOSE',
#  'POSIX_SPAWN_DUP2',
#  'POSIX_SPAWN_OPEN',
#  'PRIO_DARWIN_BG',
#  'PRIO_DARWIN_NONUI',
# ...
