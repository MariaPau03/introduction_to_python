# %% [markdown]
# # THIRD PARTY PACKAGES

# %% [markdown]
# ## numpy

# %%
conda install numpy

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# Have mutli

# %% [markdown]
# ## pandas

# %%
conda install pandas
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - bioconda
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/mariapaupijoan/miniconda3/envs/pyt
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-3.0.1               |  py314h5e21a50_0        13.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             conda-forge/osx-arm64::pandas-3.0.1-py314h5e21a50_0
#
#
#
# ...
#
# ...

# %%
import pandas as pd

# %% [markdown]
# ## matplotlib

# %% [markdown]
# ## scipy

# %% [markdown]
# ## skilearn
